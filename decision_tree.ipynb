# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('loan_approval_dataset.csv')

# %%
x=df.drop(columns='Loan_Approved')
y=df['Loan_Approved']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
num_col=x.select_dtypes(include='number').columns
# cat_col=df.select_dtypes(exclude='number')
obj_col=x.select_dtypes(include='object').columns

# %%
# model_1=DecisionTreeRegressor()
# model_2=DecisionTreeClassifier()

# %%
preprocessing=ColumnTransformer(
    transformers=[

        ('encoding',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),obj_col)
    ]
)

# %%
main_pipeline=Pipeline(
    steps=[
        ('pre',preprocessing),
        ('model_1',DecisionTreeRegressor())
    ]
)

# %%
main_pipeline.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 main_pipeline.fit(xtrain,ytrain)
#
# File c:\Users\chand\anaconda3\Edunet\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\chand\anaconda3\Edunet\Lib\site-packages\sklearn\pipeline.py:621, in Pipeline.fit(self, X, y, **params)
#     615     if self._final_estimator != "passthrough":
#     616         last_step_params = self._get_metadata_for_step(
#     617             step_idx=len(self) - 1,
#     618             step_params=routed_params[self.steps[-1][0]],
#     619             all_params=params,
#     620         )
# --> 621         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     623 return self
#
# File c:\Users\chand\anaconda3\Edunet\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\chand\anaconda3\Edunet\Lib\site-packages\sklearn\tree\_classes.py:1407, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1377 @_fit_context(prefer_skip_nested_validation=True)
#    1378 def fit(self, X, y, sample_weight=None, check_input=True):
#    1379     """Build a decision tree regressor from the training set (X, y).
#    1380
#    1381     Parameters
#    (...)
#    1404         Fitted estimator.
#    1405     """
# -> 1407     super()._fit(
#    1408         X,
#    1409         y,
#    1410         sample_weight=sample_weight,
#    1411         check_input=check_input,
#    1412     )
#    1413     return self
#
# File c:\Users\chand\anaconda3\Edunet\Lib\site-packages\sklearn\tree\_classes.py:321, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     318     self.n_classes_ = np.array(self.n_classes_, dtype=np.intp)
#     320 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 321     y = np.ascontiguousarray(y, dtype=DOUBLE)
#     323 max_depth = np.iinfo(np.int32).max if self.max_depth is None else self.max_depth
#     325 if isinstance(self.min_samples_leaf, numbers.Integral):
#
# ValueError: could not convert string to float: 'No'
